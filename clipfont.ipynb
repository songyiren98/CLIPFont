# %%
# Download Miniconda installation script
# !wget https://repo.anaconda.com/miniconda/Miniconda3-latest-Linux-x86_64.sh
# Make it executable
# !chmod +x Miniconda3-latest-Linux-x86_64.sh
# Start installation in silent mode
# !bash ./Miniconda3-latest-Linux-x86_64.sh -b -f -p /usr/local
# Make conda packages available in current environmentimport 
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# !git clone https://github.com/BachiLi/diffvg
# %cd diffvg
# !git submodule update --init --recursive
# !conda install -y pytorch torchvision -c pytorch
# !conda install -y numpy
# !conda install -y scikit-image
# !conda install -y -c anaconda cmake
# !conda install -y -c conda-forge ffmpeg
# !pip install svgwrite
# !pip install svgpathtools
# !pip install cssutils
# !pip install numba
# !pip install torch-tools
# !pip install visdom
# !pip install opencv-python
# !pip install sklearn
# !pip install ipykernel
# !python setup.py install
# !pip install ftfy regex tqdm      
# !pip install git+https://github.com/openai/CLIP.git --no-deps
# !git clone https://github.com/songyiren98/CLIPFont.git

# %%
import os
path="/content/diffvg/CLIPFont/CLIPfont_code/clipfont/"
os.chdir(path)
os.listdir(path)
# !python clip_font.py
import cv2
import matplotlib.pyplot as plt
image = cv2.imread("/content/diffvg/CLIPFont/CLIPfont_code/clipfont/results/body/iter_7070.png")
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()
image2 = cv2.imread("/content/diffvg/CLIPFont/CLIPfont_code/clipfont/results/body/iter_9090.png")
plt.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))
plt.show()
image2 = cv2.imread("/content/diffvg/CLIPFont/CLIPfont_code/clipfont/results/body/iter_140140.png")
plt.imshow(cv2.cvtColor(image2, cv2.COLOR_BGR2RGB))
plt.show()
